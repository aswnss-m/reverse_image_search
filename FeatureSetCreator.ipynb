# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

# Load pre-trained VGG16 model without the classification layers
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(400, 400, 3))

# %%
from PIL import Image
from tensorflow.keras.preprocessing.image import img_to_array

def get_feature_vector(img_path):
    # Load image from file path and resize to 400x400
    img = Image.open(img_path)
    img = img.resize((400, 400))
    
    # Convert image to numpy array and expand dimensions to match input shape of VGG16
    x = img_to_array(img)
    x = np.expand_dims(x, axis=0)
    
    # Preprocess input image using the same method as used during training VGG16
    x = preprocess_input(x)
    
    # Pass the preprocessed image through the VGG16 model and obtain the feature vector
    features = base_model.predict(x)
    
    # Flatten the feature vector and return as 1D array
    feature_vector = features.flatten()
    return feature_vector

# %%
import os

# Define the directory path where the logos are stored
logo_dir = './test'

# Initialize an empty array to store the feature vectors
feature_vectors = []

# Iterate through all the image files in the logos directory
for filename in os.listdir(logo_dir):
    # Check if the file is a PNG image
    if filename.endswith('.png'):
        # Construct the full file path
        img_path = os.path.join(logo_dir, filename)
        # Obtain the feature vector for the image and append to the feature_vectors array
        feature_vector = get_feature_vector(img_path)
        feature_vectors.append(feature_vector)

# Save the feature_vectors array as a numpy array to disk
np.save('feature_vectors.npy', feature_vectors)

# %%
f_vect = np.load('./feature_vectors.npy')
print(f_vect.shape)

# %% [markdown]
# ## Subdividing the dataset to do parllel processing

# %%
with open("./LLD-logo_files/files.txt",'r') as f:
    count = 0
    subset = []
    i = 0
    for line in f:
        count+=1
        subset.append(line)
        if count == 10000:
            count = 0
            with open("subset_files_{}.txt".format(str(i)),'w') as w:
                w.write("".join(subset))
            subset = []
            i+=1
    if len(subset) > 0:
        with open("subset_files_{}.txt".format(str(i)),'w') as w:
            w.write("".join(subset))
        subset = []

# %% [markdown]
# ## Trying Batch Processing

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np
from tqdm import tqdm_notebook

# Load pre-trained VGG16 model without the classification layers
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %%
from PIL import Image
from tensorflow.keras.preprocessing.image import img_to_array

def get_feature_vector(img_path):
    # Load image from file path and resize to 400x400
    print(img_path)
    img = Image.open(img_path)
    if img.mode == 'RGBA':
        img = img.convert('RGB')
    img = img.resize((224, 224))
    # Convert image to numpy array and expand dimensions to match input shape of VGG16
    x = img_to_array(img)
    x = np.expand_dims(x, axis=0)
    
    # Preprocess input image using the same method as used during training VGG16
    x = preprocess_input(x)
    
    # Pass the preprocessed image through the VGG16 model and obtain the feature vector
    features = base_model.predict(x)
    
    # Flatten the feature vector and return as 1D array
    feature_vector = features.flatten()
    return feature_vector

def divide_dataset_into_subsets(path):
    import os

    subset_folder = path

    subset_files = os.listdir(subset_folder)

    all_subset_names = []
    for file_name in subset_files:
        if file_name.endswith('.txt'):
            file_path = os.path.join(subset_folder, file_name)
            with open(file_path, 'r') as file:
                subset_names = file.read().splitlines()
                all_subset_names.append(subset_names)

    return all_subset_names
def process_photos(photo_subset):
    # Process each photo in the subset
    subset_feature_vectors = []
    for photo_path in tqdm_notebook(photo_subset, desc='Processing subset'):
        # Process the photo and extract the feature vector
        feature_vector = get_feature_vector(photo_path)
        print("done one")
        subset_feature_vectors.append(feature_vector)
    
    return subset_feature_vectors

# %%
import os
import numpy as np
import pandas as pd

# Define the directory path where the logos are stored
logo_dir = './LLD-logo_files/LLD-logo-files/'

# Initialize empty arrays to store the feature vectors and labels
feature_vectors = []
labels = []

# Iterate through all the image files in the logos directory
with open("./LLD-logo_files/subsets/subset_files_12.txt") as f:
    filenames = f.read().split("\n")

for filename in filenames:
    # Check if the file is a PNG image
    if filename.endswith('.png'):
        # Construct the full file path
        img_path = os.path.join(logo_dir, filename)
        # Obtain the feature vector for the image and append it to the feature_vectors array
        feature_vector = get_feature_vector(img_path)
        feature_vectors.append(feature_vector)
        # Extract the label from the filename and append it to the labels array
        label = filename.split('.')[0]  # Assuming the label is the part of the filename before the extension
        labels.append(label)

# Convert the feature_vectors and labels arrays to numpy arrays
feature_vectors = np.array(feature_vectors)
labels = np.array(labels)

# Create a pandas DataFrame with the feature vectors and labels
data = pd.DataFrame({'Feature Vector': feature_vectors, 'Label': labels})

# Save the DataFrame as a CSV file
data.to_csv('annotated_feature_vectors_12.csv', index=False)

# %%
import os
import numpy as np
import pandas as pd

# Define the directory path where the logos are stored
logo_dir = './LLD-logo_files/LLD-logo-files/'

# Initialize empty lists to store the feature vectors and labels
feature_vectors = []
labels = []

# Iterate through all the image files in the logos directory
with open("./LLD-logo_files/subsets/subset_files_12.txt") as f:
    filenames = f.read().split("\n")[:10]

for filename in filenames:
    # Check if the file is a PNG image
    if filename.endswith('.png'):
        # Construct the full file path
        img_path = os.path.join(logo_dir, filename)
        # Obtain the feature vector for the image and append it to the feature_vectors list
        feature_vector = get_feature_vector(img_path)
        
        if len(feature_vector) > 0:
            feature_vectors.append(feature_vector)
            # Extract the label from the filename and append it to the labels list
            label = filename.split('.')[0]  # Assuming the label is the part of the filename before the extension
            labels.append(label)

# Convert the feature_vectors and labels lists to numpy arrays
feature_vectors = np.array(feature_vectors)
labels = np.array(labels)

# Save the feature_vectors array as a numpy file
np.save('feature_vectors_12.npy', feature_vectors)

dataframe_vectors = [vector.flatten() for vector in feature_vectors]

# Check if the lengths of feature_vectors and labels are the same
if len(dataframe_vectors) == len(labels):
    # Create a pandas DataFrame with the feature vectors and labels
    data = pd.DataFrame({'Label': labels, 'Feature Vector': dataframe_vectors})

    # Save the DataFrame as a CSV file
    data.to_csv('annotated_feature_vectors_12.csv', index=False)
else:
    print("Error: Length mismatch between feature vectors and labels.")
# Out:
# ./LLD-logo_files/LLD-logo-files/worldoptions.png
# 1/1 [==============================] - 0s 114ms/step
# ./LLD-logo_files/LLD-logo-files/worldoweb.png
# 1/1 [==============================] - 0s 102ms/step
# ./LLD-logo_files/LLD-logo-files/worldpac.png
# 1/1 [==============================] - 0s 112ms/step
# ./LLD-logo_files/LLD-logo-files/worldpackers.png
# 1/1 [==============================] - 0s 118ms/step
# ./LLD-logo_files/LLD-logo-files/worldpadeltour.png
# 1/1 [==============================] - 0s 115ms/step
# ./LLD-logo_files/LLD-logo-files/worldpainter.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/worldpay.png
# 1/1 [==============================] - 0s 101ms/step
# ./LLD-logo_files/LLD-logo-files/worldpolicy.png
# 1/1 [==============================] - 0s 104ms/step
# ./LLD-logo_files/LLD-logo-files/worldpoliticsreview.png
# 1/1 [==============================] - 0s 112ms/step
# ./LLD-logo_files/LLD-logo-files/worldpressphoto.png
# 1/1 [==============================] - 0s 99ms/step

# %%
import os
import numpy as np
import pandas as pd

# Define the directory path where the logos are stored
logo_dir = './LLD-logo_files/LLD-logo-files/'

# Initialize empty lists to store the feature vectors and labels
feature_vectors = []
labels = []

# Iterate through all the image files in the logos directory
with open("./LLD-logo_files/subsets/subset_files_12.txt") as f:
    filenames = f.read().split("\n")

for filename in filenames:
    # Check if the file is a PNG image
    if filename.endswith('.png'):
        # Construct the full file path
        img_path = os.path.join(logo_dir, filename)
        # Obtain the feature vector for the image and append it to the feature_vectors list
        feature_vector = get_feature_vector(img_path)
        
        if len(feature_vector) > 0:
            feature_vectors.append(feature_vector)
            # Extract the label from the filename and append it to the labels list
            label = filename.split('.')[0]  # Assuming the label is the part of the filename before the extension
            labels.append(label)

# Convert the feature_vectors and labels lists to numpy arrays
feature_vectors = np.array(feature_vectors)
labels = np.array(labels)

# Round the feature vectors to a specified number of decimal places (e.g., 6)
feature_vectors = np.round(feature_vectors, decimals=6)

# Save the feature_vectors array as a numpy file
np.save('feature_vectors_12.npy', feature_vectors)

dataframe_vectors = [vector.flatten() for vector in feature_vectors]

# Check if the lengths of feature_vectors and labels are the same
if len(dataframe_vectors) == len(labels):
    # Create a pandas DataFrame with the feature vectors and labels
    data = pd.DataFrame({'Label': labels, 'Feature Vector': dataframe_vectors})

    # Save the DataFrame as a CSV file
    data.to_csv('annotated_feature_vectors_12.csv', index=False)
else:
    print("Error: Length mismatch between feature vectors and labels.")
# Out:
# ./LLD-logo_files/LLD-logo-files/worldoptions.png
# 1/1 [==============================] - 0s 118ms/step
# ./LLD-logo_files/LLD-logo-files/worldoweb.png
# 1/1 [==============================] - 0s 126ms/step
# ./LLD-logo_files/LLD-logo-files/worldpac.png
# 1/1 [==============================] - 0s 107ms/step
# ./LLD-logo_files/LLD-logo-files/worldpackers.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/worldpadeltour.png
# 1/1 [==============================] - 0s 111ms/step
# ./LLD-logo_files/LLD-logo-files/worldpainter.png
# 1/1 [==============================] - 0s 112ms/step
# ./LLD-logo_files/LLD-logo-files/worldpay.png
# 1/1 [==============================] - 0s 106ms/step
# ./LLD-logo_files/LLD-logo-files/worldpolicy.png
# 1/1 [==============================] - 0s 101ms/step
# ./LLD-logo_files/LLD-logo-files/worldpoliticsreview.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/worldpressphoto.png
# 1/1 [==============================] - 0s 133ms/step
# ./LLD-logo_files/LLD-logo-files/worldrag.png
# 1/1 [==============================] - 0s 115ms/step
# ./LLD-logo_files/LLD-logo-files/worldreader.png
# 1/1 [==============================] - 0s 132ms/step
# ./LLD-logo_files/LLD-logo-files/worldremit.png
# 1/1 [==============================] - 0s 109ms/step
# ./LLD-logo_files/LLD-logo-files/worldrowing.png
# 1/1 [==============================] - 0s 119ms/step
# ./LLD-logo_files/LLD-logo-files/worlds-away.png
# 1/1 [==============================] - 0s 114ms/step
# ./LLD-logo_files/LLD-logo-files/worldsbestbars.png
# 1/1 [==============================] - 0s 110ms/step
# ./LLD-logo_files/LLD-logo-files/worldsciencefestival.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/worldscienceu.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/worldscreen.png
# 1/1 [==============================] - 0s 114ms/step
# ./LLD-logo_files/LLD-logo-files/worldshare.png
# 1/1 [==============================] - 0s 109ms/step
# ./LLD-logo_files/LLD-logo-files/worldslist.png
# 1/1 [==============================] - 0s 108ms/step
# ./LLD-logo_files/LLD-logo-files/worldsoffood.png
# 1/1 [==============================] - 0s 116ms/step
# ./LLD-logo_files/LLD-logo-files/worldsoft-wbs.png
# 1/1 [==============================] - 0s 126ms/step
# ./LLD-logo_files/LLD-logo-files/worldspice.png
# 1/1 [==============================] - 0s 102ms/step
# ./LLD-logo_files/LLD-logo-files/worldstores.png
# 1/1 [==============================] - 0s 107ms/step
# ./LLD-logo_files/LLD-logo-files/worldstream.png
# 1/1 [==============================] - 0s 109ms/step
# ./LLD-logo_files/LLD-logo-files/worldswimsuit.png
# 1/1 [==============================] - 0s 108ms/step
# ./LLD-logo_files/LLD-logo-files/worldswithoutend.png
# 1/1 [==============================] - 0s 109ms/step
# ./LLD-logo_files/LLD-logo-files/worldtattooers.png
# 1/1 [==============================] - 0s 113ms/step
# ./LLD-logo_files/LLD-logo-files/worldtechit.png
# 1/1 [==============================] - 0s 116ms/step
# ./LLD-logo_files/LLD-logo-files/worldtimebuddy.png
# 1/1 [==============================] - 0s 121ms/step
# ./LLD-logo_files/LLD-logo-files/worldtrademarkreview.png
# 1/1 [==============================] - 0s 112ms/step
# ./LLD-logo_files/LLD-logo-files/worldtravelguide.png
# 1/1 [==============================] - 0s 117ms/step
# ./LLD-logo_files/LLD-logo-files/worldvectorlogo.png
# 1/1 [==============================] - 0s 106ms/step
# ./LLD-logo_files/LLD-logo-files/worldventures.png
# 1/1 [==============================] - 0s 121ms/step
# ./LLD-logo_files/LLD-logo-files/worldversus.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/worldview.png
# 1/1 [==============================] - 0s 129ms/step
# ./LLD-logo_files/LLD-logo-files/worldvision.png
# 1/1 [==============================] - 0s 107ms/step
# ./LLD-logo_files/LLD-logo-files/worldwatch.png
# 1/1 [==============================] - 0s 104ms/step
# ./LLD-logo_files/LLD-logo-files/worldwide-invest.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/worldwide-rs.png
# 1/1 [==============================] - 0s 115ms/step
# ./LLD-logo_files/LLD-logo-files/worldwidebrands.png
# 1/1 [==============================] - 0s 104ms/step
# ./LLD-logo_files/LLD-logo-files/worldwidecases.png
# 1/1 [==============================] - 0s 104ms/step
# ./LLD-logo_files/LLD-logo-files/worldwidedx.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/worldwideerc.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/worldwidelearn.png
# 1/1 [==============================] - 0s 123ms/step
# ./LLD-logo_files/LLD-logo-files/worldwidemarkets.png
# 1/1 [==============================] - 0s 109ms/step
# ./LLD-logo_files/LLD-logo-files/worldwidemetric.png
# 1/1 [==============================] - 0s 112ms/step
# ./LLD-logo_files/LLD-logo-files/worldworksgames.png
# 1/1 [==============================] - 0s 107ms/step
# ./LLD-logo_files/LLD-logo-files/worleyparsons.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/worlize.png
# 1/1 [==============================] - 0s 116ms/step
# ./LLD-logo_files/LLD-logo-files/wormholeit.png
# 1/1 [==============================] - 0s 117ms/step
# ./LLD-logo_files/LLD-logo-files/wormly.png
# 1/1 [==============================] - 0s 114ms/step
# ./LLD-logo_files/LLD-logo-files/wornontv.png
# 1/1 [==============================] - 0s 102ms/step
# ./LLD-logo_files/LLD-logo-files/worrydream.png
# 1/1 [==============================] - 0s 118ms/step
# ./LLD-logo_files/LLD-logo-files/worshipartistry.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/worshiponline.png
# 1/1 [==============================] - 0s 123ms/step
# ./LLD-logo_files/LLD-logo-files/worshipplanning.png
# 1/1 [==============================] - 0s 104ms/step
# ./LLD-logo_files/LLD-logo-files/worshiptogether.png
# 1/1 [==============================] - 0s 102ms/step
# ./LLD-logo_files/LLD-logo-files/wort-suchen.png
# 1/1 [==============================] - 0s 119ms/step
# ./LLD-logo_files/LLD-logo-files/wort.png
# 1/1 [==============================] - 0s 106ms/step
# ./LLD-logo_files/LLD-logo-files/worten.png
# 1/1 [==============================] - 0s 127ms/step
# ./LLD-logo_files/LLD-logo-files/worthingtonlibraries.png
# 1/1 [==============================] - 0s 133ms/step
# ./LLD-logo_files/LLD-logo-files/worthofweb.png
# 1/1 [==============================] - 0s 114ms/step
# ./LLD-logo_files/LLD-logo-files/worthwhile.png
# 1/1 [==============================] - 0s 122ms/step
# ./LLD-logo_files/LLD-logo-files/worthynews.png
# 1/1 [==============================] - 0s 111ms/step
# ./LLD-logo_files/LLD-logo-files/wortimmo.png
# 1/1 [==============================] - 0s 113ms/step
# ./LLD-logo_files/LLD-logo-files/woshiru.png
# 1/1 [==============================] - 0s 106ms/step
# ./LLD-logo_files/LLD-logo-files/wosp.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/wossel.png
# 1/1 [==============================] - 0s 129ms/step
# ./LLD-logo_files/LLD-logo-files/wosu.png
# 1/1 [==============================] - 0s 112ms/step
# ./LLD-logo_files/LLD-logo-files/wotif.png
# 1/1 [==============================] - 0s 136ms/step
# ./LLD-logo_files/LLD-logo-files/wotofo.png
# 1/1 [==============================] - 0s 114ms/step
# ./LLD-logo_files/LLD-logo-files/wotol.png
# 1/1 [==============================] - 0s 107ms/step
# ./LLD-logo_files/LLD-logo-files/wotv4women.png
# 1/1 [==============================] - 0s 102ms/step
# ./LLD-logo_files/LLD-logo-files/woundsource.png
# 1/1 [==============================] - 0s 106ms/step
# ./LLD-logo_files/LLD-logo-files/woven.png
# 1/1 [==============================] - 0s 109ms/step
# ./LLD-logo_files/LLD-logo-files/wovenlabelsuk.png
# 1/1 [==============================] - 0s 116ms/step
# ./LLD-logo_files/LLD-logo-files/wovn.png
# 1/1 [==============================] - 0s 106ms/step
# ./LLD-logo_files/LLD-logo-files/wow-petopia.png
# 1/1 [==============================] - 0s 110ms/step
# ./LLD-logo_files/LLD-logo-files/wow-portal.png
# 1/1 [==============================] - 0s 107ms/step
# ./LLD-logo_files/LLD-logo-files/wowapp.png
# 1/1 [==============================] - 0s 110ms/step
# ./LLD-logo_files/LLD-logo-files/wowasiknya.png
# 1/1 [==============================] - 0s 109ms/step
# ./LLD-logo_files/LLD-logo-files/wowcher.png
# 1/1 [==============================] - 0s 133ms/step
# ./LLD-logo_files/LLD-logo-files/wowdeal.png
# 1/1 [==============================] - 0s 106ms/step
# ./LLD-logo_files/LLD-logo-files/wowfilm.png
# 1/1 [==============================] - 0s 106ms/step
# ./LLD-logo_files/LLD-logo-files/wowfreestuff.png
# 1/1 [==============================] - 0s 119ms/step
# ./LLD-logo_files/LLD-logo-files/wowgame.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/wowkitchen.png
# 1/1 [==============================] - 0s 114ms/step
# ./LLD-logo_files/LLD-logo-files/wowlazymacros.png
# 1/1 [==============================] - 0s 132ms/step
# ./LLD-logo_files/LLD-logo-files/wowme.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/wowone.png
# 1/1 [==============================] - 0s 124ms/step
# ./LLD-logo_files/LLD-logo-files/wowow.png
# 1/1 [==============================] - 0s 107ms/step
# ./LLD-logo_files/LLD-logo-files/wowpass.png
# 1/1 [==============================] - 0s 124ms/step
# ./LLD-logo_files/LLD-logo-files/wowrack.png
# 1/1 [==============================] - 0s 115ms/step
# ./LLD-logo_files/LLD-logo-files/wowraider.png
# 1/1 [==============================] - 0s 100ms/step
# ./LLD-logo_files/LLD-logo-files/wowshop.png
# 1/1 [==============================] - 0s 114ms/step
# ./LLD-logo_files/LLD-logo-files/wowslider.png
# 1/1 [==============================] - 0s 109ms/step
# ./LLD-logo_files/LLD-logo-files/wowtalk.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/wowthemes.png
# 1/1 [==============================] - 0s 98ms/step
# ./LLD-logo_files/LLD-logo-files/wowtokenprices.png
# 1/1 [==============================] - 0s 102ms/step
# ./LLD-logo_files/LLD-logo-files/wowtrack.png
# 1/1 [==============================] - 0s 124ms/step
# ./LLD-logo_files/LLD-logo-files/wowtrendy.png
# 1/1 [==============================] - 0s 102ms/step
# ./LLD-logo_files/LLD-logo-files/wowtrk.png
# 1/1 [==============================] - 0s 111ms/step
# ./LLD-logo_files/LLD-logo-files/wowubuntu.png
# 1/1 [==============================] - 0s 113ms/step
# ./LLD-logo_files/LLD-logo-files/wowwiki.png
# 1/1 [==============================] - 0s 106ms/step
# ./LLD-logo_files/LLD-logo-files/wowwo.png
# 1/1 [==============================] - 0s 104ms/step
# ./LLD-logo_files/LLD-logo-files/wowza.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/woxter.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/wozmeldpunt.png
# 1/1 [==============================] - 0s 100ms/step
# ./LLD-logo_files/LLD-logo-files/wp-buddy.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/wp-customerarea.png
# 1/1 [==============================] - 0s 124ms/step
# ./LLD-logo_files/LLD-logo-files/wp-ninjas.png
# 1/1 [==============================] - 0s 99ms/step
# ./LLD-logo_files/LLD-logo-files/wp-property-hive.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/wp-puzzle.png
# 1/1 [==============================] - 0s 98ms/step
# ./LLD-logo_files/LLD-logo-files/wp-rocket.png
# 1/1 [==============================] - 0s 111ms/step
# ./LLD-logo_files/LLD-logo-files/wp-snippets.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/wp101.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/wp365.png
# 1/1 [==============================] - 0s 106ms/step
# ./LLD-logo_files/LLD-logo-files/wp3dmodels.png
# 1/1 [==============================] - 0s 108ms/step
# ./LLD-logo_files/LLD-logo-files/wpacademy.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/wpaisle.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/wpapp.png
# 1/1 [==============================] - 0s 102ms/step
# ./LLD-logo_files/LLD-logo-files/wparena.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/wpavanzado.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/wpbean.png
# 1/1 [==============================] - 0s 114ms/step
# ./LLD-logo_files/LLD-logo-files/wpbets.png
# 1/1 [==============================] - 0s 111ms/step
# ./LLD-logo_files/LLD-logo-files/wpbox.png
# 1/1 [==============================] - 0s 120ms/step
# ./LLD-logo_files/LLD-logo-files/wpbsa.png
# 1/1 [==============================] - 0s 109ms/step
# ./LLD-logo_files/LLD-logo-files/wpcasa.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/wpchandra.png
# 1/1 [==============================] - 0s 98ms/step
# ./LLD-logo_files/LLD-logo-files/wpcharitable.png
# 1/1 [==============================] - 0s 102ms/step
# ./LLD-logo_files/LLD-logo-files/wpchef.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/wpcore.png
# 1/1 [==============================] - 0s 113ms/step
# ./LLD-logo_files/LLD-logo-files/wpcu.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/wpdiscuz.png
# 1/1 [==============================] - 0s 107ms/step
# ./LLD-logo_files/LLD-logo-files/wpdrudge.png
# 1/1 [==============================] - 0s 110ms/step
# ./LLD-logo_files/LLD-logo-files/wpelevation.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/wpengineer.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/wpenhance.png
# 1/1 [==============================] - 0s 120ms/step
# ./LLD-logo_files/LLD-logo-files/wpensar.png
# 1/1 [==============================] - 0s 102ms/step
# ./LLD-logo_files/LLD-logo-files/wper.png
# 1/1 [==============================] - 0s 99ms/step
# ./LLD-logo_files/LLD-logo-files/wpestate.png
# 1/1 [==============================] - 0s 117ms/step
# ./LLD-logo_files/LLD-logo-files/wpexpand.png
# 1/1 [==============================] - 0s 104ms/step
# ./LLD-logo_files/LLD-logo-files/wpexplorer.png
# 1/1 [==============================] - 0s 102ms/step
# ./LLD-logo_files/LLD-logo-files/wpfaster.png
# 1/1 [==============================] - 0s 124ms/step
# ./LLD-logo_files/LLD-logo-files/wpfilm.png
# 1/1 [==============================] - 0s 115ms/step
# ./LLD-logo_files/LLD-logo-files/wpformation.png
# 1/1 [==============================] - 0s 106ms/step
# ./LLD-logo_files/LLD-logo-files/wpforms.png
# 1/1 [==============================] - 0s 112ms/step
# ./LLD-logo_files/LLD-logo-files/wpfr.png
# 1/1 [==============================] - 0s 109ms/step
# ./LLD-logo_files/LLD-logo-files/wpfsharp.png
# 1/1 [==============================] - 0s 104ms/step
# ./LLD-logo_files/LLD-logo-files/wpgate.png
# 1/1 [==============================] - 0s 136ms/step
# ./LLD-logo_files/LLD-logo-files/wpgeodirectory.png
# 1/1 [==============================] - 0s 119ms/step
# ./LLD-logo_files/LLD-logo-files/wpgothemes.png
# 1/1 [==============================] - 0s 110ms/step
# ./LLD-logo_files/LLD-logo-files/wphub.png
# 1/1 [==============================] - 0s 108ms/step
# ./LLD-logo_files/LLD-logo-files/wphunters.png
# 1/1 [==============================] - 0s 115ms/step
# ./LLD-logo_files/LLD-logo-files/wpion.png
# 1/1 [==============================] - 0s 131ms/step
# ./LLD-logo_files/LLD-logo-files/wpjobboard.png
# 1/1 [==============================] - 0s 102ms/step
# ./LLD-logo_files/LLD-logo-files/wpjobmanager.png
# 1/1 [==============================] - 0s 111ms/step
# ./LLD-logo_files/LLD-logo-files/wpkube.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/wpkurzus.png
# 1/1 [==============================] - 0s 107ms/step
# ./LLD-logo_files/LLD-logo-files/wpl.png
# 1/1 [==============================] - 0s 118ms/step
# ./LLD-logo_files/LLD-logo-files/wplama.png
# 1/1 [==============================] - 0s 104ms/step
# ./LLD-logo_files/LLD-logo-files/wplimb.png
# 1/1 [==============================] - 0s 100ms/step
# ./LLD-logo_files/LLD-logo-files/wplogs.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/wplook.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/wplounge.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/wpmadesimple.png
# 1/1 [==============================] - 0s 110ms/step
# ./LLD-logo_files/LLD-logo-files/wpmania.png
# 1/1 [==============================] - 0s 108ms/step
# ./LLD-logo_files/LLD-logo-files/wpmatic.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/wpmatik.png
# 1/1 [==============================] - 0s 116ms/step
# ./LLD-logo_files/LLD-logo-files/wpmktgengine.png
# 1/1 [==============================] - 0s 112ms/step
# ./LLD-logo_files/LLD-logo-files/wpmood.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/wpmudev.png
# 1/1 [==============================] - 0s 104ms/step
# ./LLD-logo_files/LLD-logo-files/wpn.png
# 1/1 [==============================] - 0s 109ms/step
# ./LLD-logo_files/LLD-logo-files/wpnewsify.png
# 1/1 [==============================] - 0s 116ms/step
# ./LLD-logo_files/LLD-logo-files/wpninja.png
# 1/1 [==============================] - 0s 104ms/step
# ./LLD-logo_files/LLD-logo-files/wpnode.png
# 1/1 [==============================] - 0s 101ms/step
# ./LLD-logo_files/LLD-logo-files/wpnote.png
# 1/1 [==============================] - 0s 116ms/step
# ./LLD-logo_files/LLD-logo-files/wpnull.png
# 1/1 [==============================] - 0s 118ms/step
# ./LLD-logo_files/LLD-logo-files/wpolityce.png
# 1/1 [==============================] - 0s 117ms/step
# ./LLD-logo_files/LLD-logo-files/wponlinesupport.png
# 1/1 [==============================] - 0s 101ms/step
# ./LLD-logo_files/LLD-logo-files/wpos.png
# 1/1 [==============================] - 0s 109ms/step
# ./LLD-logo_files/LLD-logo-files/wpoven.png
# 1/1 [==============================] - 0s 97ms/step
# ./LLD-logo_files/LLD-logo-files/wppoint.png
# 1/1 [==============================] - 0s 102ms/step
# ./LLD-logo_files/LLD-logo-files/wppratico.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/wpquestions.png
# 1/1 [==============================] - 0s 112ms/step
# ./LLD-logo_files/LLD-logo-files/wpr.png
# 1/1 [==============================] - 0s 121ms/step
# ./LLD-logo_files/LLD-logo-files/wpr24.png
# 1/1 [==============================] - 0s 104ms/step
# ./LLD-logo_files/LLD-logo-files/wpremote.png
# 1/1 [==============================] - 0s 102ms/step
# ./LLD-logo_files/LLD-logo-files/wpren.png
# 1/1 [==============================] - 0s 108ms/step
# ./LLD-logo_files/LLD-logo-files/wpri.png
# 1/1 [==============================] - 0s 129ms/step
# ./LLD-logo_files/LLD-logo-files/wprichsnippets.png
# 1/1 [==============================] - 0s 100ms/step
# ./LLD-logo_files/LLD-logo-files/wpromote.png
# 1/1 [==============================] - 0s 125ms/step
# ./LLD-logo_files/LLD-logo-files/wprost.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/wprssaggregator.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/wpscans.png
# 1/1 [==============================] - 0s 100ms/step
# ./LLD-logo_files/LLD-logo-files/wpscouts.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/wpseek.png
# 1/1 [==============================] - 0s 104ms/step
# ./LLD-logo_files/LLD-logo-files/wpseo.png
# 1/1 [==============================] - 0s 102ms/step
# ./LLD-logo_files/LLD-logo-files/wpserveur.png
# 1/1 [==============================] - 0s 102ms/step
# ./LLD-logo_files/LLD-logo-files/wpsharks.png
# 1/1 [==============================] - 0s 115ms/step
# ./LLD-logo_files/LLD-logo-files/wpshop.png
# 1/1 [==============================] - 0s 99ms/step
# ./LLD-logo_files/LLD-logo-files/wpshout.png
# 1/1 [==============================] - 0s 101ms/step
# ./LLD-logo_files/LLD-logo-files/wpsimplepay.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/wpsitecare.png
# 1/1 [==============================] - 0s 118ms/step
# ./LLD-logo_files/LLD-logo-files/wpsnipp.png
# 1/1 [==============================] - 0s 98ms/step
# ./LLD-logo_files/LLD-logo-files/wpspring.png
# 1/1 [==============================] - 0s 124ms/step
# ./LLD-logo_files/LLD-logo-files/wpstagecoach.png
# 1/1 [==============================] - 0s 112ms/step
# ./LLD-logo_files/LLD-logo-files/wpsu.png
# 1/1 [==============================] - 0s 129ms/step
# ./LLD-logo_files/LLD-logo-files/wpsuperstars.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/wpt.png
# 1/1 [==============================] - 0s 126ms/step
# ./LLD-logo_files/LLD-logo-files/wptasty.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/wptavern.png
# 1/1 [==============================] - 0s 134ms/step
# ./LLD-logo_files/LLD-logo-files/wpteq.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/wpthemedetector.png
# 1/1 [==============================] - 0s 99ms/step
# ./LLD-logo_files/LLD-logo-files/wptoolkit.png
# 1/1 [==============================] - 0s 108ms/step
# ./LLD-logo_files/LLD-logo-files/wptotal.png
# 1/1 [==============================] - 0s 106ms/step
# ./LLD-logo_files/LLD-logo-files/wptouch.png
# 1/1 [==============================] - 0s 117ms/step
# ./LLD-logo_files/LLD-logo-files/wpuxsolutions.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/wpxbox.png
# 1/1 [==============================] - 0s 109ms/step
# ./LLD-logo_files/LLD-logo-files/wpzen.png
# 1/1 [==============================] - 0s 118ms/step
# ./LLD-logo_files/LLD-logo-files/wqxr.png
# 1/1 [==============================] - 0s 108ms/step
# ./LLD-logo_files/LLD-logo-files/wra.png
# 1/1 [==============================] - 0s 123ms/step
# ./LLD-logo_files/LLD-logo-files/wradio.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/wrangler.png
# 1/1 [==============================] - 0s 106ms/step
# ./LLD-logo_files/LLD-logo-files/wranglernetwork.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/wrap.png
# 1/1 [==============================] - 0s 107ms/step
# ./LLD-logo_files/LLD-logo-files/wraparts.png
# 1/1 [==============================] - 0s 109ms/step
# ./LLD-logo_files/LLD-logo-files/wrapify.png
# 1/1 [==============================] - 0s 102ms/step
# ./LLD-logo_files/LLD-logo-files/wrappixel.png
# 1/1 [==============================] - 0s 98ms/step
# ./LLD-logo_files/LLD-logo-files/wrappz.png
# 1/1 [==============================] - 0s 123ms/step
# ./LLD-logo_files/LLD-logo-files/wrbiradio.png
# 1/1 [==============================] - 0s 102ms/step
# ./LLD-logo_files/LLD-logo-files/wrdw.png
# 1/1 [==============================] - 0s 102ms/step
# ./LLD-logo_files/LLD-logo-files/wreg.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/wrek.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/wrenchscience.png
# 1/1 [==============================] - 0s 113ms/step
# ./LLD-logo_files/LLD-logo-files/wrenkitchens.png
# 1/1 [==============================] - 0s 110ms/step
# ./LLD-logo_files/LLD-logo-files/wrestdag.png
# 1/1 [==============================] - 0s 119ms/step
# ./LLD-logo_files/LLD-logo-files/wrestlerdeaths.png
# 1/1 [==============================] - 0s 118ms/step
# ./LLD-logo_files/LLD-logo-files/wrestlestat.png
# 1/1 [==============================] - 0s 101ms/step
# ./LLD-logo_files/LLD-logo-files/wrestleview.png
# 1/1 [==============================] - 0s 112ms/step
# ./LLD-logo_files/LLD-logo-files/wrestlezone.png
# 1/1 [==============================] - 0s 103ms/step
# ./LLD-logo_files/LLD-logo-files/wrestling-edge.png
# 1/1 [==============================] - 0s 123ms/step
# ./LLD-logo_files/LLD-logo-files/wrestlingcity.png
# 1/1 [==============================] - 0s 101ms/step
# ./LLD-logo_files/LLD-logo-files/wrestlingecho.png
# 1/1 [==============================] - 0s 104ms/step
# ./LLD-logo_files/LLD-logo-files/wrestlinggames.png
# 1/1 [==============================] - 0s 105ms/step
# ./LLD-logo_files/LLD-logo-files/wrestlingitalia.png
# 1/1 [==============================] - 0s 124ms/step
# ./LLD-logo_files/LLD-logo-files/wrestlingmart.png
# 1/1 [==============================] - 0s 109ms/step
# ./LLD-logo_files/LLD-logo-files/wrestlingweb.png
# 1/1 [==============================] - 0s 102ms/step
# ./LLD-logo_files/LLD-logo-files/wretchedradio.png
# 1/1 [==============================] - 0s 123ms/step
# ./LLD-logo_files/LLD-logo-files/wrexham.png
# 1/1 [==============================] - 0s 149ms/step
# ./LLD-logo_files/LLD-logo-files/wrha.png
# 1/1 [==============================] - 0s 102ms/step
# ./LLD-logo_files/LLD-logo-files/wri.png
# 1/1 [==============================] - 0s 132ms/step
# ./LLD-logo_files/LLD-logo-files/wright20.png
# 1/1 [==============================] - 0s 108ms/step
# ./LLD-logo_files/LLD-logo-files/wrighthassall.png
# 1/1 [==============================] - 0s 130ms/step
# ./LLD-logo_files/LLD-logo-files/wrist-band.png
# 1/1 [==============================] - 0s 148ms/step
# ./LLD-logo_files/LLD-logo-files/wristwatchreview.png
# 1/1 [==============================] - 0s 133ms/step
# ./LLD-logo_files/LLD-logo-files/write4fun.png
# 1/1 [==============================] - 0s 130ms/step
# ./LLD-logo_files/LLD-logo-files/writeage.png
# 1/1 [==============================] - 0s 124ms/step
# ./LLD-logo_files/LLD-logo-files/writeaprisoner.png
# 1/1 [==============================] - 0s 137ms/step
# ./LLD-logo_files/LLD-logo-files/writeawriting.png
# 1/1 [==============================] - 0s 137ms/step
# ./LLD-logo_files/LLD-logo-files/writecheck.png
# 1/1 [==============================] - 0s 140ms/step
# ./LLD-logo_files/LLD-logo-files/writefullapp.png
# 1/1 [==============================] - 0s 114ms/step
# ./LLD-logo_files/LLD-logo-files/writehindi.png
# 1/1 [==============================] - 0s 146ms/step
# ./LLD-logo_files/LLD-logo-files/writelab.png
# 1/1 [==============================] - 0s 121ms/step
# ./LLD-logo_files/LLD-logo-files/writelearnearn.png
# 1/1 [==============================] - 0s 125ms/step
# ./LLD-logo_files/LLD-logo-files/writemaps.png
# 1/1 [==============================] - 0s 141ms/step
# ./LLD-logo_files/LLD-logo-files/writemonkey.png
# 1/1 [==============================] - 0s 134ms/step
# ./LLD-logo_files/LLD-logo-files/writemyessay4me.png
# 1/1 [==============================] - 0s 123ms/step
# ./LLD-logo_files/LLD-logo-files/writemypapers.png
# 1/1 [==============================] - 0s 135ms/step
# ./LLD-logo_files/LLD-logo-files/writephponline.png
# 1/1 [==============================] - 0s 124ms/step
# ./LLD-logo_files/LLD-logo-files/writeraccess.png
# 1/1 [==============================] - 0s 141ms/step
# ./LLD-logo_files/LLD-logo-files/writerduet.png
# 1/1 [==============================] - 0s 118ms/step
# ./LLD-logo_files/LLD-logo-files/writereader.png
# 1/1 [==============================] - 0s 124ms/step
# ./LLD-logo_files/LLD-logo-files/writersalmanac.png
# 1/1 [==============================] - 0s 144ms/step
# ./LLD-logo_files/LLD-logo-files/writersdigest.png
# 1/1 [==============================] - 0s 120ms/step
# ./LLD-logo_files/LLD-logo-files/writersstore.png
# 1/1 [==============================] - 0s 124ms/step
# ./LLD-logo_files/LLD-logo-files/writerunboxed.png
# 1/1 [==============================] - 0s 141ms/step
# ./LLD-logo_files/LLD-logo-files/writethatessay.png
# 1/1 [==============================] - 0s 127ms/step
# ./LLD-logo_files/LLD-logo-files/writeupcafe.png
# 1/1 [==============================] - 0s 137ms/step
# ./LLD-logo_files/LLD-logo-files/writewellapp.png
# 1/1 [==============================] - 0s 118ms/step
# ./LLD-logo_files/LLD-logo-files/writeyboards.png
# 1/1 [==============================] - 0s 138ms/step
# ./LLD-logo_files/LLD-logo-files/writingcommons.png
# 1/1 [==============================] - 0s 155ms/step
# ./LLD-logo_files/LLD-logo-files/writingprompts.png
# 1/1 [==============================] - 0s 122ms/step
# ./LLD-logo_files/LLD-logo-files/writtle.png
# 1/1 [==============================] - 0s 130ms/step
# ./LLD-logo_files/LLD-logo-files/wrlc.png
# 1/1 [==============================] - 0s 133ms/step
# ./LLD-logo_files/LLD-logo-files/wrmc.png
# 1/1 [==============================] - 0s 120ms/step
# ./LLD-logo_files/LLD-logo-files/wrongplanet.png
# 1/1 [==============================] - 0s 133ms/step
# ./LLD-logo_files/LLD-logo-files/wrongweather.png
# 1/1 [==============================] - 0s 133ms/step
# ./LLD-logo_files/LLD-logo-files/wroops.png
# 1/1 [==============================] - 0s 141ms/step
# ./LLD-logo_files/LLD-logo-files/wror.png
# 1/1 [==============================] - 0s 118ms/step
# ./LLD-logo_files/LLD-logo-files/wrs.png
# 1/1 [==============================] - 0s 124ms/step
# ./LLD-logo_files/LLD-logo-files/wrshealth.png
# 1/1 [==============================] - 0s 144ms/step
# ./LLD-logo_files/LLD-logo-files/wruf.png
# 1/1 [==============================] - 0s 121ms/step
# ./LLD-logo_files/LLD-logo-files/ws1.png
# 1/1 [==============================] - 0s 152ms/step
# ./LLD-logo_files/LLD-logo-files/wsau.png
# 1/1 [==============================] - 0s 118ms/step
# ./LLD-logo_files/LLD-logo-files/wsba.png
# 1/1 [==============================] - 0s 134ms/step
# ./LLD-logo_files/LLD-logo-files/wsbradio.png
# 1/1 [==============================] - 0s 127ms/step
# ./LLD-logo_files/LLD-logo-files/wsbt.png
# 1/1 [==============================] - 0s 125ms/step
# ./LLD-logo_files/LLD-logo-files/wsc.png
# 1/1 [==============================] - 0s 140ms/step
# ./LLD-logo_files/LLD-logo-files/wscal.png
# 1/1 [==============================] - 0s 132ms/step
# ./LLD-logo_files/LLD-logo-files/wscc.png
# 1/1 [==============================] - 0s 141ms/step
# ./LLD-logo_files/LLD-logo-files/wscom.png
# 1/1 [==============================] - 0s 124ms/step
# ./LLD-logo_files/LLD-logo-files/wscubetech.png
# 1/1 [==============================] - 0s 147ms/step
# ./LLD-logo_files/LLD-logo-files/wsdata.png
# 1/1 [==============================] - 0s 139ms/step
# ./LLD-logo_files/LLD-logo-files/wsdot.png
# 1/1 [==============================] - 0s 127ms/step
# ./LLD-logo_files/LLD-logo-files/wseas.png
# 1/1 [==============================] - 0s 124ms/step
# ./LLD-logo_files/LLD-logo-files/wsecu.png
# 1/1 [==============================] - 0s 132ms/step
# ./LLD-logo_files/LLD-logo-files/wseetk.png
# 1/1 [==============================] - 0s 136ms/step
# ./LLD-logo_files/LLD-logo-files/wset.png
# 1/1 [==============================] - 0s 143ms/step
# ./LLD-logo_files/LLD-logo-files/wsetglobal.png
# 1/1 [==============================] - 0s 136ms/step
# ./LLD-logo_files/LLD-logo-files/wsfm.png
# 1/1 [==============================] - 0s 126ms/step
# ./LLD-logo_files/LLD-logo-files/wshfc.png
# 1/1 [==============================] - 0s 137ms/step
# ./LLD-logo_files/LLD-logo-files/wshu.png
# 1/1 [==============================] - 0s 141ms/step
# ./LLD-logo_files/LLD-logo-files/wsieci.png
# 1/1 [==============================] - 0s 134ms/step
# ./LLD-logo_files/LLD-logo-files/wsipc.png
# 1/1 [==============================] - 0s 127ms/step
# ./LLD-logo_files/LLD-logo-files/wsitothetrade.png
# 1/1 [==============================] - 0s 121ms/step
# ./LLD-logo_files/LLD-logo-files/wsiworld.png
# 1/1 [==============================] - 0s 136ms/step
# ./LLD-logo_files/LLD-logo-files/wsjo.png
# 1/1 [==============================] - 0s 129ms/step
# ./LLD-logo_files/LLD-logo-files/wsjp.png
# 1/1 [==============================] - 0s 136ms/step
# ./LLD-logo_files/LLD-logo-files/wsjwine.png
# 1/1 [==============================] - 0s 131ms/step
# ./LLD-logo_files/LLD-logo-files/wsmamusic.png
# 1/1 [==============================] - 0s 128ms/step
# ./LLD-logo_files/LLD-logo-files/wsmintl.png
# 1/1 [==============================] - 0s 136ms/step
# ./LLD-logo_files/LLD-logo-files/wsoctv.png
# 1/1 [==============================] - 0s 137ms/step
# ./LLD-logo_files/LLD-logo-files/wsol.png
# 1/1 [==============================] - 0s 123ms/step
# ./LLD-logo_files/LLD-logo-files/wsommelier.png
# 1/1 [==============================] - 0s 137ms/step
# ./LLD-logo_files/LLD-logo-files/wsop.png
# 1/1 [==============================] - 0s 125ms/step
# ./LLD-logo_files/LLD-logo-files/wspa.png
# 1/1 [==============================] - 0s 142ms/step
# ./LLD-logo_files/LLD-logo-files/wspaper.png
# 1/1 [==============================] - 0s 136ms/step
# ./LLD-logo_files/LLD-logo-files/wspay.png
# 1/1 [==============================] - 0s 122ms/step
# ./LLD-logo_files/LLD-logo-files/wspia.png
# 1/1 [==============================] - 0s 135ms/step
# ./LLD-logo_files/LLD-logo-files/wspieram.png
# 1/1 [==============================] - 0s 129ms/step
# ./LLD-logo_files/LLD-logo-files/wspinanie.png
# 1/1 [==============================] - 0s 138ms/step
# ./LLD-logo_files/LLD-logo-files/wspolczesna.png
# 1/1 [==============================] - 0s 139ms/step
# ./LLD-logo_files/LLD-logo-files/wspolnota.png
# 1/1 [==============================] - 0s 132ms/step
# ./LLD-logo_files/LLD-logo-files/wsps.png
# 1/1 [==============================] - 0s 123ms/step
# ./LLD-logo_files/LLD-logo-files/wsr.png
# 1/1 [==============================] - 0s 132ms/step
# ./LLD-logo_files/LLD-logo-files/wssa.png
# 1/1 [==============================] - 0s 134ms/step
# ./LLD-logo_files/LLD-logo-files/wsta.png
# 1/1 [==============================] - 0s 127ms/step
# ./LLD-logo_files/LLD-logo-files/wsu.png
# 1/1 [==============================] - 0s 135ms/step
# ./LLD-logo_files/LLD-logo-files/wsupercars.png
# 1/1 [==============================] - 0s 133ms/step
# ./LLD-logo_files/LLD-logo-files/wsuraiders.png
# 1/1 [==============================] - 0s 135ms/step
# ./LLD-logo_files/LLD-logo-files/wsws.png
# 1/1 [==============================] - 0s 124ms/step
# ./LLD-logo_files/LLD-logo-files/wszib.png
# 1/1 [==============================] - 0s 141ms/step
# ./LLD-logo_files/LLD-logo-files/wszpwn.png
# 1/1 [==============================] - 0s 120ms/step
# ./LLD-logo_files/LLD-logo-files/wtamu.png
# 1/1 [==============================] - 0s 133ms/step
# ./LLD-logo_files/LLD-logo-files/wtb.png
# 1/1 [==============================] - 0s 131ms/step
# ./LLD-logo_files/LLD-logo-files/wtca.png
# 1/1 [==============================] - 0s 129ms/step
# ./LLD-logo_files/LLD-logo-files/wtcbarcelona.png
# 1/1 [==============================] - 0s 149ms/step
# ./LLD-logo_files/LLD-logo-files/wtf1.png
# 1/1 [==============================] - 0s 125ms/step
# ./LLD-logo_files/LLD-logo-files/wtfast.png
# 1/1 [==============================] - 0s 142ms/step
# ./LLD-logo_files/LLD-logo-files/wtfdiary.png
# 1/1 [==============================] - 0s 147ms/step
# ./LLD-logo_files/LLD-logo-files/wtfismyip.png
# 1/1 [==============================] - 0s 126ms/step
# ./LLD-logo_files/LLD-logo-files/wthitv.png
# 1/1 [==============================] - 0s 128ms/step
# ./LLD-logo_files/LLD-logo-files/wtmd.png
# 1/1 [==============================] - 0s 144ms/step
# ./LLD-logo_files/LLD-logo-files/wtmj.png
# 1/1 [==============================] - 0s 137ms/step
# ./LLD-logo_files/LLD-logo-files/wto.png
# 1/1 [==============================] - 0s 130ms/step
# ./LLD-logo_files/LLD-logo-files/wtoip.png
# 1/1 [==============================] - 0s 141ms/step
# ./LLD-logo_files/LLD-logo-files/wtop.png
# 1/1 [==============================] - 0s 131ms/step
# ./LLD-logo_files/LLD-logo-files/wtpack.png
# 1/1 [==============================] - 0s 150ms/step
# ./LLD-logo_files/LLD-logo-files/wtransnet.png
# 1/1 [==============================] - 0s 141ms/step
# ./LLD-logo_files/LLD-logo-files/wtsp.png
# 1/1 [==============================] - 0s 129ms/step
# ./LLD-logo_files/LLD-logo-files/wtstravel.png
# 1/1 [==============================] - 0s 134ms/step
# ./LLD-logo_files/LLD-logo-files/wttw.png
# 1/1 [==============================] - 0s 136ms/step
# ./LLD-logo_files/LLD-logo-files/wtvm.png
# 1/1 [==============================] - 0s 139ms/step
# ./LLD-logo_files/LLD-logo-files/wtvox.png
# 1/1 [==============================] - 0s 136ms/step
# ./LLD-logo_files/LLD-logo-files/wtware.png
# 1/1 [==============================] - 0s 136ms/step
# ./LLD-logo_files/LLD-logo-files/wtzupcity.png
# 1/1 [==============================] - 0s 140ms/step
# ./LLD-logo_files/LLD-logo-files/wuaki.png
# 1/1 [==============================] - 0s 144ms/step
# ./LLD-logo_files/LLD-logo-files/wuanto.png
# 1/1 [==============================] - 0s 126ms/step
# ./LLD-logo_files/LLD-logo-files/wubmachine.png
# 1/1 [==============================] - 0s 148ms/step
# ./LLD-logo_files/LLD-logo-files/wubook.png
# 1/1 [==============================] - 0s 131ms/step
# ./LLD-logo_files/LLD-logo-files/wuerth-phoenix.png
# 1/1 [==============================] - 0s 133ms/step
# ./LLD-logo_files/LLD-logo-files/wuestenrot.png
# 1/1 [==============================] - 0s 146ms/step
# ./LLD-logo_files/LLD-logo-files/wuewowas.png
# 1/1 [==============================] - 0s 125ms/step
# ./LLD-logo_files/LLD-logo-files/wuft.png
# 1/1 [==============================] - 0s 135ms/step
# ./LLD-logo_files/LLD-logo-files/wugsoku.png
# 1/1 [==============================] - 0s 140ms/step
# ./LLD-logo_files/LLD-logo-files/wulfhosting.png
# 1/1 [==============================] - 0s 141ms/step
# ./LLD-logo_files/LLD-logo-files/wulfmansworld.png
# 1/1 [==============================] - 0s 135ms/step
# ./LLD-logo_files/LLD-logo-files/wuliaoo.png
# 1/1 [==============================] - 0s 143ms/step
# ./LLD-logo_files/LLD-logo-files/wunder.png
# 1/1 [==============================] - 0s 119ms/step
# ./LLD-logo_files/LLD-logo-files/wunderagent.png
# 1/1 [==============================] - 0s 138ms/step
# ./LLD-logo_files/LLD-logo-files/wundercapital.png
# 1/1 [==============================] - 0s 133ms/step
# ./LLD-logo_files/LLD-logo-files/wunderflats.png
# 1/1 [==============================] - 0s 140ms/step
# ./LLD-logo_files/LLD-logo-files/wunderground.png
# 1/1 [==============================] - 0s 145ms/step
# ./LLD-logo_files/LLD-logo-files/wunderino.png
# 1/1 [==============================] - 0s 134ms/step
# ./LLD-logo_files/LLD-logo-files/wunderkarten.png
# 1/1 [==============================] - 0s 136ms/step
# ./LLD-logo_files/LLD-logo-files/wunderlandgroup.png
# 1/1 [==============================] - 0s 137ms/step
# ./LLD-logo_files/LLD-logo-files/wunderweib.png
# 1/1 [==============================] - 0s 141ms/step
# ./LLD-logo_files/LLD-logo-files/wunjoguitars.png
# 1/1 [==============================] - 0s 133ms/step
# ./LLD-logo_files/LLD-logo-files/wunsch-hund.png
# 1/1 [==============================] - 0s 128ms/step
# ./LLD-logo_files/LLD-logo-files/wunschblatt.png
# 1/1 [==============================] - 0s 145ms/step
# ./LLD-logo_files/LLD-logo-files/wunschkennzeichen.png
# 1/1 [==============================] - 0s 130ms/step
# ./LLD-logo_files/LLD-logo-files/wunschliste.png
# 1/1 [==============================] - 0s 143ms/step
# ./LLD-logo_files/LLD-logo-files/wuoppy.png
# 1/1 [==============================] - 0s 125ms/step
# ./LLD-logo_files/LLD-logo-files/wupperinst.png
# 1/1 [==============================] - 0s 132ms/step
# ./LLD-logo_files/LLD-logo-files/wur.png
# 1/1 [==============================] - 0s 150ms/step
# ./LLD-logo_files/LLD-logo-files/wurmonline.png
# 1/1 [==============================] - 0s 125ms/step
# ./LLD-logo_files/LLD-logo-files/wuro.png
# 1/1 [==============================] - 0s 141ms/step
# ./LLD-logo_files/LLD-logo-files/wustl.png
# 1/1 [==============================] - 0s 147ms/step
# ./LLD-logo_files/LLD-logo-files/wutangclan.png
# 1/1 [==============================] - 0s 126ms/step
# ./LLD-logo_files/LLD-logo-files/wuv.png
# 1/1 [==============================] - 0s 142ms/step
# ./LLD-logo_files/LLD-logo-files/wuwear.png
# 1/1 [==============================] - 0s 129ms/step
# ./LLD-logo_files/LLD-logo-files/wuwm.png
# 1/1 [==============================] - 0s 144ms/step
# ./LLD-logo_files/LLD-logo-files/wuzzuf.png
# 1/1 [==============================] - 0s 123ms/step
# ./LLD-logo_files/LLD-logo-files/wvbs.png
# 1/1 [==============================] - 0s 131ms/step
# ./LLD-logo_files/LLD-logo-files/wvc.png
# 1/1 [==============================] - 0s 132ms/step
# ./LLD-logo_files/LLD-logo-files/wvcycling.png
# 1/1 [==============================] - 0s 138ms/step
# ./LLD-logo_files/LLD-logo-files/wvdnr.png
# 1/1 [==============================] - 0s 162ms/step
# ./LLD-logo_files/LLD-logo-files/wvia.png
# 1/1 [==============================] - 0s 128ms/step
# ./LLD-logo_files/LLD-logo-files/wvik.png
# 1/1 [==============================] - 0s 139ms/step
# ./LLD-logo_files/LLD-logo-files/wvls.png
# 1/1 [==============================] - 0s 135ms/step
# ./LLD-logo_files/LLD-logo-files/wvnet.png
# 1/1 [==============================] - 0s 137ms/step
# ./LLD-logo_files/LLD-logo-files/wvpublic.png
# 1/1 [==============================] - 0s 147ms/step
# ./LLD-logo_files/LLD-logo-files/wvumedicine.png
# 1/1 [==============================] - 0s 139ms/step
# ./LLD-logo_files/LLD-logo-files/wvusports.png
# 1/1 [==============================] - 0s 135ms/step
# ./LLD-logo_files/LLD-logo-files/ww2awards.png
# 1/1 [==============================] - 0s 132ms/step
# ./LLD-logo_files/LLD-logo-files/ww2talk.png
# 1/1 [==============================] - 0s 149ms/step
# ./LLD-logo_files/LLD-logo-files/ww2today.png
# 1/1 [==============================] - 0s 158ms/step
# ./LLD-logo_files/LLD-logo-files/wwbw.png
# 1/1 [==============================] - 0s 133ms/step
# ./LLD-logo_files/LLD-logo-files/wwdrums.png
# 1/1 [==============================] - 0s 142ms/step
# ./LLD-logo_files/LLD-logo-files/wwe.png
# 1/1 [==============================] - 0s 152ms/step
# ./LLD-logo_files/LLD-logo-files/wweeddoo.png
# 1/1 [==============================] - 0s 136ms/step
# ./LLD-logo_files/LLD-logo-files/wwf.png
# 1/1 [==============================] - 0s 140ms/step
# ./LLD-logo_files/LLD-logo-files/wwgate.png
# 1/1 [==============================] - 0s 130ms/step
# ./LLD-logo_files/LLD-logo-files/wwhardware.png
# 1/1 [==============================] - 0s 135ms/step
# ./LLD-logo_files/LLD-logo-files/wwin.png
# 1/1 [==============================] - 0s 163ms/step
# ./LLD-logo_files/LLD-logo-files/wwl.png
# 1/1 [==============================] - 0s 139ms/step
# ./LLD-logo_files/LLD-logo-files/wwnlive.png
# 1/1 [==============================] - 0s 153ms/step
# ./LLD-logo_files/LLD-logo-files/wwnorton.png
# 1/1 [==============================] - 0s 144ms/step
# ./LLD-logo_files/LLD-logo-files/wwoof.png
# 1/1 [==============================] - 0s 128ms/step
# ./LLD-logo_files/LLD-logo-files/wwos.png
# 1/1 [==============================] - 0s 147ms/step
# ./LLD-logo_files/LLD-logo-files/wwoz.png
# 1/1 [==============================] - 0s 147ms/step
# ./LLD-logo_files/LLD-logo-files/wwt.png
# 1/1 [==============================] - 0s 129ms/step
# ./LLD-logo_files/LLD-logo-files/wwtechteam.png
# 1/1 [==============================] - 0s 143ms/step
# ./LLD-logo_files/LLD-logo-files/wwu.png
# 1/1 [==============================] - 0s 133ms/step
# ./LLD-logo_files/LLD-logo-files/www2016.png
# 1/1 [==============================] - 0s 133ms/step
# ./LLD-logo_files/LLD-logo-files/wwwpromoter.png
# 1/1 [==============================] - 0s 138ms/step
# ./LLD-logo_files/LLD-logo-files/wwx4u.png
# 1/1 [==============================] - 0s 137ms/step
# ./LLD-logo_files/LLD-logo-files/wxchallenge.png
# 1/1 [==============================] - 0s 160ms/step
# ./LLD-logo_files/LLD-logo-files/wxcharts.png
# 1/1 [==============================] - 0s 129ms/step
# ./LLD-logo_files/LLD-logo-files/wxow.png
# 1/1 [==============================] - 0s 168ms/step
# ./LLD-logo_files/LLD-logo-files/wxxv25.png
# 1/1 [==============================] - 0s 131ms/step
# ./LLD-logo_files/LLD-logo-files/wxyz.png
# 1/1 [==============================] - 0s 134ms/step
# ./LLD-logo_files/LLD-logo-files/wya.png
# 1/1 [==============================] - 0s 147ms/step
# ./LLD-logo_files/LLD-logo-files/wyattresearch.png
# 1/1 [==============================] - 0s 138ms/step
# ./LLD-logo_files/LLD-logo-files/wybieramlaptopa.png
# 1/1 [==============================] - 0s 148ms/step
# ./LLD-logo_files/LLD-logo-files/wybieramprojekt.png
# 1/1 [==============================] - 0s 142ms/step
# ./LLD-logo_files/LLD-logo-files/wyday.png
# 1/1 [==============================] - 0s 129ms/step
# ./LLD-logo_files/LLD-logo-files/wydr.png
# 1/1 [==============================] - 0s 134ms/step
# ./LLD-logo_files/LLD-logo-files/wyep.png
# 1/1 [==============================] - 0s 149ms/step
# ./LLD-logo_files/LLD-logo-files/wyg.png
# 1/1 [==============================] - 0s 147ms/step
# ./LLD-logo_files/LLD-logo-files/wyliodrin.png
# 1/1 [==============================] - 0s 140ms/step
# ./LLD-logo_files/LLD-logo-files/wymt.png
# 1/1 [==============================] - 0s 136ms/step
# ./LLD-logo_files/LLD-logo-files/wyncode.png
# 1/1 [==============================] - 0s 135ms/step
# ./LLD-logo_files/LLD-logo-files/wyndhamap.png
# 1/1 [==============================] - 0s 137ms/step
# ./LLD-logo_files/LLD-logo-files/wyndhamathome.png
# 1/1 [==============================] - 0s 139ms/step
# ./LLD-logo_files/LLD-logo-files/wyndhamjade.png
# 1/1 [==============================] - 0s 148ms/step
# ./LLD-logo_files/LLD-logo-files/wyndhamrewards.png
# 1/1 [==============================] - 0s 136ms/step
# ./LLD-logo_files/LLD-logo-files/wynk.png
# 1/1 [==============================] - 0s 137ms/step
# ./LLD-logo_files/LLD-logo-files/wyofile.png
# 1/1 [==============================] - 0s 141ms/step
# ./LLD-logo_files/LLD-logo-files/wyolotto.png
# 1/1 [==============================] - 0s 135ms/step
# ./LLD-logo_files/LLD-logo-files/wyomind.png
# 1/1 [==============================] - 0s 145ms/step
# ./LLD-logo_files/LLD-logo-files/wyomovies.png
# 1/1 [==============================] - 0s 149ms/step
# ./LLD-logo_files/LLD-logo-files/wypracowania24.png
# 1/1 [==============================] - 0s 149ms/step
# ./LLD-logo_files/LLD-logo-files/wyre.png
# 1/1 [==============================] - 0s 142ms/step
# ./LLD-logo_files/LLD-logo-files/wysada.png
# 1/1 [==============================] - 0s 137ms/step
# ./LLD-logo_files/LLD-logo-files/wyscout.png
# 1/1 [==============================] - 0s 144ms/step
# ./LLD-logo_files/LLD-logo-files/wysokienapiecie.png
# 1/1 [==============================] - 0s 155ms/step
# ./LLD-logo_files/LLD-logo-files/wyssgarten.png
# 1/1 [==============================] - 0s 148ms/step
# ./LLD-logo_files/LLD-logo-files/wysylajtaniej.png
# 1/1 [==============================] - 0s 151ms/step
# ./LLD-logo_files/LLD-logo-files/wywrota.png
# 1/1 [==============================] - 0s 137ms/step
# ./LLD-logo_files/LLD-logo-files/wywy.png
# 1/1 [==============================] - 0s 147ms/step
# ./LLD-logo_files/LLD-logo-files/wyzowl.png
# 1/1 [==============================] - 0s 147ms/step
# ./LLD-logo_files/LLD-logo-files/wzb.png
# 1/1 [==============================] - 0s 136ms/step
# ./LLD-logo_files/LLD-logo-files/wzfona.png
# 1/1 [==============================] - 0s 133ms/step
# ./LLD-logo_files/LLD-logo-files/wzonline.png
# 1/1 [==============================] - 0s 155ms/step
# ./LLD-logo_files/LLD-logo-files/wzzm13.png
# 1/1 [==============================] - 0s 143ms/step
# ./LLD-logo_files/LLD-logo-files/x-airways.png
# 1/1 [==============================] - 0s 150ms/step
# ./LLD-logo_files/LLD-logo-files/x-cart.png
# 1/1 [==============================] - 0s 127ms/step
# ./LLD-logo_files/LLD-logo-files/x-passwords.png
# 1/1 [==============================] - 0s 153ms/step
# ./LLD-logo_files/LLD-logo-files/x10hosting.png
# 1/1 [==============================] - 0s 137ms/step
# ./LLD-logo_files/LLD-logo-files/x21.png
# 1/1 [==============================] - 0s 146ms/step
# ./LLD-logo_files/LLD-logo-files/x264.png
# 1/1 [==============================] - 0s 129ms/step
# ./LLD-logo_files/LLD-logo-files/x265.png
# 1/1 [==============================] - 0s 147ms/step
# ./LLD-logo_files/LLD-logo-files/x2vol.png
# 1/1 [==============================] - 0s 137ms/step
# ./LLD-logo_files/LLD-logo-files/x3sports.png
# 1/1 [==============================] - 0s 150ms/step
# ...
# 1/1 [==============================] - 0s 224ms/step
# ./LLD-logo_files/LLD-logo-files/zpacks.png
# 1/1 [==============================] - 0s 256ms/step
# ./LLD-logo_files/LLD-logo-files/zpalette.png
# 1/1 [==============================] - 0s 268ms/step
# ./LLD-logo_files/LLD-logo-files/zpanelcp.png
# 1/1 [==============================] - 0s 253ms/step
# ./LLD-logo_files/LLD-logo-files/zpazurem.png
# 1/1 [==============================] - 0s 248ms/step
# ./LLD-logo_files/LLD-logo-files/zpid.png
# 1/1 [==============================] - 0s 222ms/step
# ./LLD-logo_files/LLD-logo-files/zpizza.png
# 1/1 [==============================] - 0s 257ms/step
# ./LLD-logo_files/LLD-logo-files/zplane.png
# 1/1 [==============================] - 0s 292ms/step
# ./LLD-logo_files/LLD-logo-files/zpsb.png
# 1/1 [==============================] - 0s 228ms/step
# ./LLD-logo_files/LLD-logo-files/zqgame.png
# 1/1 [==============================] - 0s 258ms/step
# ./LLD-logo_files/LLD-logo-files/zqnow.png
# 1/1 [==============================] - 0s 244ms/step
# ./LLD-logo_files/LLD-logo-files/zqsd.png
# 1/1 [==============================] - 0s 233ms/step
# ./LLD-logo_files/LLD-logo-files/zra.png
# 1/1 [==============================] - 0s 255ms/step
# ./LLD-logo_files/LLD-logo-files/zrankings.png
# 1/1 [==============================] - 0s 261ms/step
# ./LLD-logo_files/LLD-logo-files/zrel-porn.png
# 1/1 [==============================] - 0s 269ms/step
# ./LLD-logo_files/LLD-logo-files/zrenjaninski.png
# 1/1 [==============================] - 0s 258ms/step
# ./LLD-logo_files/LLD-logo-files/zreomusic.png
# 1/1 [==============================] - 0s 235ms/step
# ./LLD-logo_files/LLD-logo-files/zricks.png
# 1/1 [==============================] - 0s 246ms/step
# ./LLD-logo_files/LLD-logo-files/zrk.png
# 1/1 [==============================] - 0s 252ms/step
# ./LLD-logo_files/LLD-logo-files/zrock.png
# 1/1 [==============================] - 0s 222ms/step
# ./LLD-logo_files/LLD-logo-files/zrss.png
# 1/1 [==============================] - 0s 271ms/step
# ./LLD-logo_files/LLD-logo-files/zrtlab.png
# 1/1 [==============================] - 0s 272ms/step
# ./LLD-logo_files/LLD-logo-files/zrzutka.png
# 1/1 [==============================] - 0s 225ms/step
# ./LLD-logo_files/LLD-logo-files/zs.png
# 1/1 [==============================] - 0s 249ms/step
# ./LLD-logo_files/LLD-logo-files/zsl.png
# 1/1 [==============================] - 0s 250ms/step
# ./LLD-logo_files/LLD-logo-files/zsr.png
# 1/1 [==============================] - 0s 226ms/step
# ./LLD-logo_files/LLD-logo-files/zstor.png
# 1/1 [==============================] - 0s 261ms/step
# ./LLD-logo_files/LLD-logo-files/zszywka.png
# 1/1 [==============================] - 0s 256ms/step
# ./LLD-logo_files/LLD-logo-files/zte.png
# 1/1 [==============================] - 0s 218ms/step
# ./LLD-logo_files/LLD-logo-files/ztele.png
# 1/1 [==============================] - 0s 259ms/step
# ./LLD-logo_files/LLD-logo-files/zteusa.png
# 1/1 [==============================] - 0s 289ms/step
# ./LLD-logo_files/LLD-logo-files/ztex.png
# 1/1 [==============================] - 0s 248ms/step
# ./LLD-logo_files/LLD-logo-files/ztgd.png
# 1/1 [==============================] - 0s 248ms/step
# ./LLD-logo_files/LLD-logo-files/ztory.png
# 1/1 [==============================] - 0s 225ms/step
# ./LLD-logo_files/LLD-logo-files/ztylus.png
# 1/1 [==============================] - 0s 258ms/step
# ./LLD-logo_files/LLD-logo-files/zuauto.png
# 1/1 [==============================] - 0s 253ms/step
# ./LLD-logo_files/LLD-logo-files/zubaidasonline.png
# 1/1 [==============================] - 0s 226ms/step
# ./LLD-logo_files/LLD-logo-files/zuberance.png
# 1/1 [==============================] - 0s 280ms/step
# ./LLD-logo_files/LLD-logo-files/zubersoft.png
# 1/1 [==============================] - 0s 255ms/step
# ./LLD-logo_files/LLD-logo-files/zubizu.png
# 1/1 [==============================] - 0s 229ms/step
# ./LLD-logo_files/LLD-logo-files/zubronok.png
# 1/1 [==============================] - 0s 256ms/step
# ./LLD-logo_files/LLD-logo-files/zuckerpapier24.png
# 1/1 [==============================] - 0s 243ms/step
# ./LLD-logo_files/LLD-logo-files/zudy.png
# 1/1 [==============================] - 0s 234ms/step
# ./LLD-logo_files/LLD-logo-files/zuerich.png
# 1/1 [==============================] - 0s 256ms/step
# ./LLD-logo_files/LLD-logo-files/zugaina.png
# 1/1 [==============================] - 0s 246ms/step
# ./LLD-logo_files/LLD-logo-files/zuglo.png
# 1/1 [==============================] - 0s 227ms/step
# ./LLD-logo_files/LLD-logo-files/zugspitzarena.png
# 1/1 [==============================] - 0s 255ms/step
# ./LLD-logo_files/LLD-logo-files/zuhalmuzik.png
# 1/1 [==============================] - 0s 285ms/step
# ./LLD-logo_files/LLD-logo-files/zuiderhuis.png
# 1/1 [==============================] - 0s 244ms/step
# ./LLD-logo_files/LLD-logo-files/zuiki.png
# 1/1 [==============================] - 0s 228ms/step
# ./LLD-logo_files/LLD-logo-files/zuimeia.png
# 1/1 [==============================] - 0s 257ms/step
# ./LLD-logo_files/LLD-logo-files/zuji.png
# 1/1 [==============================] - 0s 283ms/step
# ./LLD-logo_files/LLD-logo-files/zukit.png
# 1/1 [==============================] - 0s 275ms/step
# ./LLD-logo_files/LLD-logo-files/zuku.png
# 1/1 [==============================] - 0s 241ms/step
# ./LLD-logo_files/LLD-logo-files/zukunft-mobilitaet.png
# 1/1 [==============================] - 0s 255ms/step
# ./LLD-logo_files/LLD-logo-files/zukunftsinstitut.png
# 1/1 [==============================] - 0s 239ms/step
# ./LLD-logo_files/LLD-logo-files/zukureview.png
# 1/1 [==============================] - 0s 243ms/step
# ./LLD-logo_files/LLD-logo-files/zulafood.png
# 1/1 [==============================] - 0s 235ms/step
# ./LLD-logo_files/LLD-logo-files/zulualphakilo.png
# 1/1 [==============================] - 0s 246ms/step
# ./LLD-logo_files/LLD-logo-files/zuludesk.png
# 1/1 [==============================] - 0s 282ms/step
# ./LLD-logo_files/LLD-logo-files/zulwa.png
# 1/1 [==============================] - 0s 279ms/step
# ./LLD-logo_files/LLD-logo-files/zuman.png
# 1/1 [==============================] - 0s 258ms/step
# ./LLD-logo_files/LLD-logo-files/zumashoes.png
# 1/1 [==============================] - 0s 243ms/step
# ./LLD-logo_files/LLD-logo-files/zumba.png
# 1/1 [==============================] - 0s 252ms/step
# ./LLD-logo_files/LLD-logo-files/zumbara.png
# 1/1 [==============================] - 0s 216ms/step
# ./LLD-logo_files/LLD-logo-files/zumbashop.png
# 1/1 [==============================] - 0s 254ms/step
# ./LLD-logo_files/LLD-logo-files/zumby.png
# 1/1 [==============================] - 0s 307ms/step
# ./LLD-logo_files/LLD-logo-files/zumepizza.png
# 1/1 [==============================] - 0s 249ms/step
# ./LLD-logo_files/LLD-logo-files/zumero.png
# 1/1 [==============================] - 0s 232ms/step
# ./LLD-logo_files/LLD-logo-files/zumex.png
# 1/1 [==============================] - 0s 261ms/step
# ./LLD-logo_files/LLD-logo-files/zumnorde.png
# 1/1 [==============================] - 0s 251ms/step
# ./LLD-logo_files/LLD-logo-files/zumper.png
# 1/1 [==============================] - 0s 262ms/step
# ./LLD-logo_files/LLD-logo-files/zumtobel.png
# 1/1 [==============================] - 0s 269ms/step
# ./LLD-logo_files/LLD-logo-files/zumub.png
# 1/1 [==============================] - 0s 227ms/step
# ./LLD-logo_files/LLD-logo-files/zund.png
# 1/1 [==============================] - 0s 256ms/step
# ./LLD-logo_files/LLD-logo-files/zunoxide.png
# 1/1 [==============================] - 0s 247ms/step
# ./LLD-logo_files/LLD-logo-files/zuora.png
# 1/1 [==============================] - 0s 254ms/step
# ./LLD-logo_files/LLD-logo-files/zupper.png
# 1/1 [==============================] - 0s 243ms/step
# ./LLD-logo_files/LLD-logo-files/zuppler.png
# 1/1 [==============================] - 0s 276ms/step
# ./LLD-logo_files/LLD-logo-files/zupportdesk.png
# 1/1 [==============================] - 0s 274ms/step
# ./LLD-logo_files/LLD-logo-files/zuragt.png
# 1/1 [==============================] - 0s 267ms/step
# ./LLD-logo_files/LLD-logo-files/zurbrigg.png
# 1/1 [==============================] - 0s 278ms/step
# ./LLD-logo_files/LLD-logo-files/zurbrueggen.png
# 1/1 [==============================] - 0s 252ms/step
# ./LLD-logo_files/LLD-logo-files/zurchers.png
# 1/1 [==============================] - 0s 271ms/step
# ./LLD-logo_files/LLD-logo-files/zurich.png
# 1/1 [==============================] - 0s 250ms/step
# ./LLD-logo_files/LLD-logo-files/zurichlife.png
# 1/1 [==============================] - 0s 276ms/step
# ./LLD-logo_files/LLD-logo-files/zurichopenair.png
# 1/1 [==============================] - 0s 256ms/step
# ./LLD-logo_files/LLD-logo-files/zurmo.png
# 1/1 [==============================] - 0s 224ms/step
# ./LLD-logo_files/LLD-logo-files/zurnal24.png
# 1/1 [==============================] - 0s 259ms/step
# ./LLD-logo_files/LLD-logo-files/zurple.png
# 1/1 [==============================] - 0s 284ms/step
# ./LLD-logo_files/LLD-logo-files/zuru.png
# 1/1 [==============================] - 0s 250ms/step
# ./LLD-logo_files/LLD-logo-files/zurvita.png
# 1/1 [==============================] - 0s 232ms/step
# ./LLD-logo_files/LLD-logo-files/zusammengebaut.png
# 1/1 [==============================] - 0s 255ms/step
# ./LLD-logo_files/LLD-logo-files/zutec.png
# 1/1 [==============================] - 0s 278ms/step
# ./LLD-logo_files/LLD-logo-files/zuto.png
# 1/1 [==============================] - 0s 259ms/step
# ./LLD-logo_files/LLD-logo-files/zuver.png
# 1/1 [==============================] - 0s 254ms/step
# ./LLD-logo_files/LLD-logo-files/zuzeu.png
# 1/1 [==============================] - 0s 233ms/step
# ./LLD-logo_files/LLD-logo-files/zuzu.png
# 1/1 [==============================] - 0s 249ms/step
# ./LLD-logo_files/LLD-logo-files/zuzuhotels.png
# 1/1 [==============================] - 0s 243ms/step
# ./LLD-logo_files/LLD-logo-files/zuzupopo.png
# 1/1 [==============================] - 0s 274ms/step
# ./LLD-logo_files/LLD-logo-files/zvarot.png
# 1/1 [==============================] - 0s 259ms/step
# ./LLD-logo_files/LLD-logo-files/zvei.png
# 1/1 [==============================] - 0s 229ms/step
# ./LLD-logo_files/LLD-logo-files/zverivdom.png
# 1/1 [==============================] - 0s 253ms/step
# ./LLD-logo_files/LLD-logo-files/zvetnoe.png
# 1/1 [==============================] - 0s 249ms/step
# ./LLD-logo_files/LLD-logo-files/zvex.png
# 1/1 [==============================] - 0s 268ms/step
# ./LLD-logo_files/LLD-logo-files/zvistka.png
# 1/1 [==============================] - 0s 258ms/step
# ./LLD-logo_files/LLD-logo-files/zvooq.png
# 1/1 [==============================] - 0s 227ms/step
# ./LLD-logo_files/LLD-logo-files/zvukobaza.png
# 1/1 [==============================] - 0s 273ms/step
# ./LLD-logo_files/LLD-logo-files/zvv.png
# 1/1 [==============================] - 0s 260ms/step
# ./LLD-logo_files/LLD-logo-files/zvw.png
# 1/1 [==============================] - 0s 225ms/step
# ./LLD-logo_files/LLD-logo-files/zwaluwhoeve.png
# 1/1 [==============================] - 0s 307ms/step
# ./LLD-logo_files/LLD-logo-files/zwame.png
# 1/1 [==============================] - 0s 247ms/step
# ./LLD-logo_files/LLD-logo-files/zwangerschapspagina.png
# 1/1 [==============================] - 0s 231ms/step
# ./LLD-logo_files/LLD-logo-files/zwartopwit.png
# 1/1 [==============================] - 0s 251ms/step
# ./LLD-logo_files/LLD-logo-files/zwave.png
# 1/1 [==============================] - 0s 253ms/step
# ./LLD-logo_files/LLD-logo-files/zwaveproducts.png
# 1/1 [==============================] - 0s 299ms/step
# ./LLD-logo_files/LLD-logo-files/zweezle.png
# 1/1 [==============================] - 0s 250ms/step
# ./LLD-logo_files/LLD-logo-files/zweitausendeins.png
# 1/1 [==============================] - 0s 232ms/step
# ./LLD-logo_files/LLD-logo-files/zwerfkei.png
# 1/1 [==============================] - 0s 276ms/step
# ./LLD-logo_files/LLD-logo-files/zwergenstadt.png
# 1/1 [==============================] - 0s 257ms/step
# ./LLD-logo_files/LLD-logo-files/zwezda.png
# 1/1 [==============================] - 0s 271ms/step
# ./LLD-logo_files/LLD-logo-files/zwick.png
# 1/1 [==============================] - 0s 248ms/step
# ./LLD-logo_files/LLD-logo-files/zwickau.png
# 1/1 [==============================] - 0s 240ms/step
# ./LLD-logo_files/LLD-logo-files/zwierciadlo.png
# 1/1 [==============================] - 0s 252ms/step
# ./LLD-logo_files/LLD-logo-files/zwift.png
# 1/1 [==============================] - 0s 234ms/step
# ./LLD-logo_files/LLD-logo-files/zwijsen.png
# 1/1 [==============================] - 0s 253ms/step
# ./LLD-logo_files/LLD-logo-files/zwilling.png
# 1/1 [==============================] - 0s 269ms/step
# ./LLD-logo_files/LLD-logo-files/zwinkr.png
# 1/1 [==============================] - 0s 230ms/step
# ./LLD-logo_files/LLD-logo-files/zwischengas.png
# 1/1 [==============================] - 0s 257ms/step
# ./LLD-logo_files/LLD-logo-files/zwitserleven.png
# 1/1 [==============================] - 0s 272ms/step
# ./LLD-logo_files/LLD-logo-files/zwivel.png
# 1/1 [==============================] - 0s 242ms/step
# ./LLD-logo_files/LLD-logo-files/zwjate.png
# 1/1 [==============================] - 0s 260ms/step
# ./LLD-logo_files/LLD-logo-files/zwp-online.png
# 1/1 [==============================] - 0s 263ms/step
# ./LLD-logo_files/LLD-logo-files/zwsoft.png
# 1/1 [==============================] - 0s 247ms/step
# ./LLD-logo_files/LLD-logo-files/zybez.png
# 1/1 [==============================] - 0s 230ms/step
# ./LLD-logo_files/LLD-logo-files/zycon.png
# 1/1 [==============================] - 0s 263ms/step
# ./LLD-logo_files/LLD-logo-files/zycoo.png
# 1/1 [==============================] - 0s 253ms/step
# ./LLD-logo_files/LLD-logo-files/zycus.png
# 1/1 [==============================] - 0s 250ms/step
# ./LLD-logo_files/LLD-logo-files/zygotebody.png
# 1/1 [==============================] - 0s 253ms/step
# ./LLD-logo_files/LLD-logo-files/zymanga.png
# 1/1 [==============================] - 0s 226ms/step
# ./LLD-logo_files/LLD-logo-files/zymdeals.png
# 1/1 [==============================] - 0s 263ms/step
# ./LLD-logo_files/LLD-logo-files/zyme.png
# 1/1 [==============================] - 0s 266ms/step
# ./LLD-logo_files/LLD-logo-files/zymphonies.png
# 1/1 [==============================] - 0s 280ms/step
# ./LLD-logo_files/LLD-logo-files/zymr.png
# 1/1 [==============================] - 0s 250ms/step
# ./LLD-logo_files/LLD-logo-files/zyn22.png
# 1/1 [==============================] - 0s 224ms/step
# ./LLD-logo_files/LLD-logo-files/zynaptiq.png
# 1/1 [==============================] - 0s 261ms/step
# ./LLD-logo_files/LLD-logo-files/zyncrender.png
# 1/1 [==============================] - 0s 247ms/step
# ./LLD-logo_files/LLD-logo-files/zyndio.png
# 1/1 [==============================] - 0s 271ms/step
# ./LLD-logo_files/LLD-logo-files/zynewave.png
# 1/1 [==============================] - 0s 256ms/step
# ./LLD-logo_files/LLD-logo-files/zynga.png
# 1/1 [==============================] - 0s 228ms/step
# ./LLD-logo_files/LLD-logo-files/zynthian.png
# 1/1 [==============================] - 0s 258ms/step
# ./LLD-logo_files/LLD-logo-files/zyoin.png
# 1/1 [==============================] - 0s 250ms/step
# ./LLD-logo_files/LLD-logo-files/zype.png
# 1/1 [==============================] - 0s 266ms/step
# ./LLD-logo_files/LLD-logo-files/zyppys.png
# 1/1 [==============================] - 0s 273ms/step
# ./LLD-logo_files/LLD-logo-files/zypresse.png
# 1/1 [==============================] - 0s 228ms/step
# ./LLD-logo_files/LLD-logo-files/zyrardow.png
# 1/1 [==============================] - 0s 246ms/step
# ./LLD-logo_files/LLD-logo-files/zyteli.png
# 1/1 [==============================] - 0s 264ms/step
# ./LLD-logo_files/LLD-logo-files/zywave.png
# 1/1 [==============================] - 0s 285ms/step
# ./LLD-logo_files/LLD-logo-files/zyxel.png
# 1/1 [==============================] - 0s 273ms/step
# ./LLD-logo_files/LLD-logo-files/zzdats.png
# 1/1 [==============================] - 0s 246ms/step
# ./LLD-logo_files/LLD-logo-files/zzish.png
# 1/1 [==============================] - 0s 241ms/step
# ./LLD-logo_files/LLD-logo-files/zzixx.png
# 1/1 [==============================] - 0s 226ms/step
# ./LLD-logo_files/LLD-logo-files/zzp-nederland.png
# 1/1 [==============================] - 0s 247ms/step
# ./LLD-logo_files/LLD-logo-files/zzperformance.png
# 1/1 [==============================] - 0s 273ms/step
# ./LLD-logo_files/LLD-logo-files/zzrock.png
# 1/1 [==============================] - 0s 288ms/step

# %%
feature_vectors = np.load('feature_vectors_12.npy')

# %%
query_image_path = 'C:/Users/ACER/Documents/GitHub/mini-project/LLD-logo_files/fakes/yabupushelberg2.png'
query_feature_vector = get_feature_vector(query_image_path)
# Out:
# C:/Users/ACER/Documents/GitHub/mini-project/LLD-logo_files/fakes/yabupushelberg2.png
# 1/1 [==============================] - 0s 115ms/step

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity_scores = cosine_similarity(query_feature_vector.reshape(1, -1), feature_vectors)

# %%
sorted_indices = np.argsort(similarity_scores)[0][::-1]

# %%
k = 10
top_k_indices = sorted_indices[:k]
similar_images = []
for index in top_k_indices:
    similar_image_path = filenames[index]  # Assuming filenames contains the paths of the images
    similarity_score = similarity_scores[0][index]
    similar_images.append((similar_image_path, similarity_score))

# %%
similar_images
# Out:
# [('yabupushelberg.png', 0.7308096),
#  ('xyht.png', 0.44533214),
#  ('zkipster.png', 0.41436666),
#  ('yosisamra.png', 0.4047302),
#  ('worldversus.png', 0.39549258),
#  ('yabancidizi.png', 0.39183703),
#  ('zizki.png', 0.38815054),
#  ('zems.png', 0.38811046),
#  ('zago.png', 0.3856465),
#  ('zindigo.png', 0.37309796)]

# %%
import os
import shutil


source_dir = '.\\LLD-logo_files\\LLD-logo-files\\'
destination_dir = './results/'

# Create the destination directory if it doesn't exist
if not os.path.exists(destination_dir):
    os.makedirs(destination_dir)

# Copy the similar images to the destination directory
for image_name, _ in similar_images:
    source_path = os.path.join(source_dir, image_name)
    destination_path = os.path.join(destination_dir, image_name)
    shutil.copyfile(source_path, destination_path)

print("Image files copied successfully!")
# Out:
# Image files copied successfully!
